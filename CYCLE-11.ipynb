# %%
#searching - normal
l = [1,2,3,4,5,6,7]
k = int(input("searching element : "))
for i in l:
  if(i == k):
    print("Elemet found")
else:
  print("Element not found")
# Out:
# searching element : 5
# Elemet found
# Element not found

# %% [markdown]
# LINEAR SEARCH

# %%
arr = ['r','a','v','i','t','e','j','a']
k = input("Enter searching element : ")
found = False
for i in range(len(arr)):
  if(arr[i] == k):
    print("Element found at ",i)
    Found = True

if (Found == False):
  print("Element not found")
# Out:
# Enter searching elemente
# Element found at  5

# %% [markdown]
# BINARY SEARCH

# %%
a = [10,20,30,40,50]
l = 0
h = 4
se = int(input("Enter searching element : "))
while(l<=h):
  mid = (l+h)//2
  if(a[mid] < se):
    l = mid+1
  elif(a[mid] > se):
    h = mid-1
  else:
    print("Element found at ",mid)
    break
# Out:
# Enter searching element : 50
# Element found at  4
