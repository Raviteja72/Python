# %%
from math import sqrt

# %%
def isPrime(n):
    if (n % 2 != 0):
        for i in range(3, int(sqrt(n)), 2):
             if (n % i == 0):
                    return False
        return True
    else:
        return False

# %%
isPrime(151)
# Out:
# True
